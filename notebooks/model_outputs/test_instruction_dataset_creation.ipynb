# %%
import pandas as pd

# %%
df_test = pd.read_csv('../files/test_dataset.csv')

# %%
df_test.sample(10)
# Out:
#      query_id                                       patient_note       doc_id  \
# 318        18  1. This is a 78 year-old male with h/o BPH s/p...  NCT03129789
# 48         18  1. This is a 78 year-old male with h/o BPH s/p...  NCT04541615
# 381        72  1. The patient is a 16-year-old girl recently ...  NCT01793168
# 295        35  1. The patient is a 15 year old girl with the ...  NCT02765581
# 337        26  1. A 45-year-old woman was referred to the eme...  NCT03534739
# 364        26  1. A 45-year-old woman was referred to the eme...  NCT03327688
# 215        41  1. A 57-year old farmer was diagnosed with Par...  NCT03019757
# 62          1  1. Patient is a 45-year-old man with a history...  NCT04132739
# 39         41  1. A 57-year old farmer was diagnosed with Par...  NCT03317808
# 332        18  1. This is a 78 year-old male with h/o BPH s/p...  NCT01073241
#
#                                            trial_title  \
# ...

# %%
import data_processing.patient_trial_match as ptm

# %%
dp = ptm.DataProcessor(model="gpt-4")

df_result = dp.process(df_input=df_test, output_filepath="../files/test_instruction_dataset.csv")
# Out:
# iteration:  499
#
# model:  gpt-4
#
# total number of instances:  500
#
# total time (seconds):  4912.797
# total time (minutes):  81.88
# total attempts number:  543
#
# average number of attempts per iteration:  1.086
# average time per iteration (s):  9.826
