# %%
import pandas as pd

# %%
df_test = pd.read_csv('../files/test_dataset.csv')

# %%
df_test.sample(10)
# Out:
#      query_id                                       patient_note       doc_id  \
# 465        19  1. 65 yo man with history of CAD and prior MI,...  NCT02126631
# 59         67  1. A Pap smear in a 54-year-old woman revealed...  NCT04129320
# 48         18  1. This is a 78 year-old male with h/o BPH s/p...  NCT04541615
# 116        19  1. 65 yo man with history of CAD and prior MI,...  NCT01296022
# 419        26  1. A 45-year-old woman was referred to the eme...  NCT01708109
# 202        18  1. This is a 78 year-old male with h/o BPH s/p...  NCT00765388
# 252        68  1. The patient is a 23-year-old man who came t...  NCT01263301
# 170        13  1. 62 yo male with hx of CVA, neurogenic bladd...  NCT01915004
# 378        18  1. This is a 78 year-old male with h/o BPH s/p...  NCT03973619
# 267        19  1. 65 yo man with history of CAD and prior MI,...  NCT01548352
#
#                                            trial_title  \
# ...

# %%
import data_processing.patient_trial_match as ptm

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
trial_match_model = os.getenv("TRIAL_MATCH_MODEL")

# %%
dp = ptm.DataProcessor(model=trial_match_model)

df_result = dp.process(df_input=df_test, output_filepath="../files/trial_match_model_output.csv")
# Out:
# iteration:  499
#
# model:  ft:gpt-3.5-turbo-0125:personal:kx-trial-match:9FVE7cAL
#
# total number of instances:  500
#
# total time (seconds):  997.606
# total time (minutes):  16.627
# total attempts number:  527
#
# average number of attempts per iteration:  1.054
# average time per iteration (s):  1.995
