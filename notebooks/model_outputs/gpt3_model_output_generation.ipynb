# %%
import pandas as pd

# %%
df_test = pd.read_csv('../files/test_dataset.csv')

# %%
df_test.sample(10)
# Out:
#      query_id                                       patient_note       doc_id  \
# 275        26  1. A 45-year-old woman was referred to the eme...  NCT00370084
# 462        68  1. The patient is a 23-year-old man who came t...  NCT02270593
# 405        41  1. A 57-year old farmer was diagnosed with Par...  NCT01768832
# 431        41  1. A 57-year old farmer was diagnosed with Par...  NCT00433654
# 149        19  1. 65 yo man with history of CAD and prior MI,...  NCT03810846
# 184        68  1. The patient is a 23-year-old man who came t...  NCT03066388
# 310        18  1. This is a 78 year-old male with h/o BPH s/p...  NCT01527812
# 417        68  1. The patient is a 23-year-old man who came t...  NCT00604916
# 327        18  1. This is a 78 year-old male with h/o BPH s/p...  NCT03502213
# 205        68  1. The patient is a 23-year-old man who came t...  NCT02205541
#
#                                            trial_title  \
# ...

# %%
import data_processing.patient_trial_match as ptm

# %%
dp = ptm.DataProcessor(model="gpt-3.5-turbo-0125")

df_result = dp.process(df_input=df_test, output_filepath="../files/gpt3_model_output.csv")
# Out:
# iteration:  499
#
# model:  gpt-3.5-turbo-0125
#
# total number of instances:  500
#
# total time (seconds):  1209.865
# total time (minutes):  20.164
# total attempts number:  528
#
# average number of attempts per iteration:  1.056
# average time per iteration (s):  2.42
