# %%
base_filepath = '../files/test_dataset.csv'
valid_filepath = '../files/test_instruction_dataset.csv'

for_evaluation_list = [
    {"model_name": "gpt-trial-match", "filepath": '../files/trial_match_model_output.csv'},
    {"model_name": "gpt-3.5-turbo", "filepath": '../files/gpt3_model_output.csv'},
]

# %%
import evaluation.evaluator as evl

# %%
evaluator = evl.Evaluator(base_filepath, valid_filepath, for_evaluation_list)

# %%
evaluator.get_criterion_level_label_report()
# Out:
# Label level evaluation
#
#  Overall evaluation metrics
#
#            gpt-trial-match  gpt-3.5-turbo
# accuracy          0.781563       0.691884
# precision         0.718455       0.605768
# recall            0.692778       0.605919
# F1                0.699127       0.605826
#  Evaluation metrics (Inclusion criteria)
#
#            gpt-trial-match  gpt-3.5-turbo
# accuracy          0.807556       0.698937
# precision         0.741131       0.638418
# recall            0.744619       0.671725
# F1                0.742822       0.640625
#  Evaluation metrics (Exclusion criteria)
#
#            gpt-trial-match  gpt-3.5-turbo
# accuracy          0.762402       0.686684
# precision         0.653769       0.529214
# recall            0.629154       0.522106
# F1                0.625326       0.521784
#  Accuracy score per category (Inclusion criteria)
#
#                          gpt-trial-match  gpt-3.5-turbo
# met                             0.830882       0.738971
# ...

# %%
evaluator.get_criterion_level_sentence_index_report()
# Out:
# Sentence index level evaluation
#
#  Overall evaluation metrics
#
#            gpt-trial-match  gpt-3.5-turbo
# accuracy          0.891026       0.837075
# precision         0.899736       0.869565
# recall            0.720930       0.533981
# F1                0.800469       0.661654
#  Evaluation metrics (Inclusion criteria)
#
#            gpt-trial-match  gpt-3.5-turbo
# accuracy          0.855263       0.771959
# precision         0.914286       0.875676
# recall            0.741722       0.591241
# F1                0.819013       0.705882
#  Evaluation metrics (Exclusion criteria)
#
#            gpt-trial-match  gpt-3.5-turbo
# accuracy          0.918950       0.885932
# precision         0.873134       0.852941
# recall            0.684211       0.420290
# F1                0.767213       0.563107
#  Accuracy score per category (Inclusion criteria)
#
#                          gpt-trial-match  gpt-3.5-turbo
# met                             0.809735       0.701493
# ...

# %%
evaluator.get_criterion_level_explanation_report()
# Out:
# Rationale evaluation

# %%
evaluator.get_aggregate_level_report()
